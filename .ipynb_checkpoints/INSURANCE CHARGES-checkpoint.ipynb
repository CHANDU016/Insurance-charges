# %% [markdown]
# <h1 style="font-family:Arial; font-size:32px; color:#2C3E50; text-align:center; background-color:#ECF0F1; padding:10px; border-radius:10px;">
# INSURANCE CHARGERS PREDICTION</h1>

# %% [markdown]
# <h1 style="font-family:Arial; font-size:32px; color:#2C3E50; text-align:center; background-color:#ECF0F1; padding:10px; border-radius:10px;">
# IMPORT LIBRARIES</h1>

# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("insurance.csv")

# %%
data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# <h1 style="font-family:Arial; font-size:32px; color:#2C3E50; text-align:center; background-color:#ECF0F1; padding:10px; border-radius:10px;">
# EXPLORATORY DATA ANALYSIS</h1>

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# <h1 style="font-family:Arial; font-size:32px; color:#2C3E50; text-align:center; background-color:#ECF0F1; padding:10px; border-radius:10px;">
# UNIVARIANT ANALYSIS</h1>

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.distplot(data['age'])
plt.title('Age Distribution')
plt.show()

# %%
sns.set()
plt.figure(figsize =(6,6))
sns.countplot(x = 'sex', data = data)
plt.title('SEX')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.set()
plt.figure(figsize = (6,6))
sns.distplot(data['bmi'])
plt.title('Body Mass Indication')
plt.show()

# %%
sns.set()
plt.figure(figsize=(6,6))
sns.countplot(x = 'children', data = data)
# Out:
# <Axes: xlabel='children', ylabel='count'>

# %%
data['children'].value_counts()
# Out:
# children
# 0    574
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64

# %%
sns.set()
plt.figure (figsize =(6,6))
sns.countplot(x = 'smoker', data = data)
plt.title('SMoking')
plt.show()

# %%
sns.set()
plt.figure (figsize =(6,6))
sns.countplot(x = 'region', data = data)
plt.title('region')
plt.show()

# %%
sns.set()
plt.figure (figsize =(6,6))
sns.distplot(data['charges'])
plt.title('region')
plt.show()

# %% [markdown]
# <h1 style="font-family:Arial; font-size:32px; color:#2C3E50; text-align:center; background-color:#ECF0F1; padding:10px; border-radius:10px;">
# LABEL ENCODING USING REPLACE METHOD</h1>

# %%
data.replace({'sex' : {'male': 0,'female': 1}}, inplace =True)

# %%
data.replace({'smoker' :{'yes':0, 'no':1}}, inplace =True)

# %%
data['region'].unique()
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
data.replace({'region':{'southwest' : 1, 'southeast':0, 'northeast':2, 'northwest':3}}, inplace =True)

# %% [markdown]
# <h1 style="font-family:Arial; font-size:32px; color:#2C3E50; text-align:center; background-color:#ECF0F1; padding:10px; border-radius:10px;">
# DATA PARTITIONING</h1>

# %%
x = data.drop(['charges'], axis =1)

# %%
y = data['charges']

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# <h1 style="font-family:Arial; font-size:32px; color:#2C3E50; text-align:center; background-color:#ECF0F1; padding:10px; border-radius:10px;">
# STRATIFICATION</h1>

# %%
stratify = pd.qcut(data['charges'], q=4, labels=False)  # Quartiles

# %%
x_train,x_test,y_train,y_test = train_test_split(x, y, random_state = 2,stratify = stratify,test_size =0.2)

# %%
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
# Out:
# (1070, 6) (268, 6) (1070,) (268,)

# %% [markdown]
# <h1 style="font-family:Arial; font-size:32px; color:#2C3E50; text-align:center; background-color:#ECF0F1; padding:10px; border-radius:10px;">
# MODELLING </h1>

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predict = model.predict(x_train)

# %%
predict
# Out:
# array([10482.03730708, 24552.77896877, 31319.41396046, ...,
#        29210.49933585, 15100.15544918, 13913.29998574])

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
metrics.r2_score(y_train, predict)
# Out:
# 0.7449551470122517

# %%
predict2 = model.predict(x_test)

# %%
metrics.r2_score(y_test, predict2)
# Out:
# 0.7677385931369326

# %%
input = (31,1,25,74,0,1)

inputtonumpy = np.asarray(input)

# %%
inputtoreshape = inputtonumpy.reshape(1,-1)

# %%
new = model.predict(inputtoreshape)

# %%
new
# Out:
# array([60380.44086451])

# %% [markdown]
# <h1 style="font-family:Arial; font-size:32px; color:#2C3E50; text-align:center; background-color:#ECF0F1; padding:10px; border-radius:10px;">
# Ordinary Least Square</h1>

# %%
import statsmodels.api as sm
X = sm.add_constant(x)
model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                charges   R-squared:                       0.750
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     667.1
# Date:                Tue, 05 Aug 2025   Prob (F-statistic):               0.00
# Time:                        19:40:05   Log-Likelihood:                -13549.
# No. Observations:                1338   AIC:                         2.711e+04
# Df Residuals:                    1331   BIC:                         2.715e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.083e+04   1087.719      9.957      0.000    8696.575     1.3e+04
# age          256.9680     11.898     21.598      0.000     233.628     280.308
# sex          128.9561    333.008      0.387      0.699    -524.321     782.233
# bmi          337.0245     28.397     11.868      0.000     281.317     392.732
# children     468.3540    137.745      3.400      0.001     198.134     738.574
# smoker     -2.387e+04    412.691    -57.833      0.000   -2.47e+04   -2.31e+04
# region       297.8372    152.286      1.956      0.051      -0.909     596.584
# ==============================================================================
# Omnibus:                      300.491   Durbin-Watson:                   2.093
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              716.279
# Skew:                           1.213   Prob(JB):                    2.90e-156
# Kurtosis:                       5.638   Cond. No.                         339.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# <h1 style="font-family:Arial; font-size:32px; color:#2C3E50; text-align:center; background-color:#ECF0F1; padding:10px; border-radius:10px;">
# Statistics model</h1>

# %%
print(model.resid)
# Out:
# 0       -8657.650436
# 1       -1712.890163
# 2       -2235.859337
# 3       17995.527383
# 4       -1946.246464
#             ...
# 1333    -1947.420136
# 1334     -865.242755
# 1335    -2507.246519
# 1336      526.244808
# 1337    -8183.861808
# Length: 1338, dtype: float64

# %%
print(model.params)
# Out:
# const       10830.405719
# age           256.967966
# sex           128.956085
# bmi           337.024519
# children      468.354047
# smoker     -23867.058687
# region        297.837207
# dtype: float64

# %%
print(model.pvalues)
# Out:
# const       1.415191e-22
# age         6.224579e-89
# sex         6.986355e-01
# bmi         5.912914e-31
# children    6.934002e-04
# smoker      0.000000e+00
# region      5.070032e-02
# dtype: float64

# %%
print(model.conf_int())
# Out:
#                      0             1
# const      8696.574581  12964.236857
# age         233.627584    280.308348
# sex        -524.320871    782.233042
# bmi         281.317200    392.731838
# children    198.133746    738.574348
# smoker   -24676.654388 -23057.462987
# region       -0.909202    596.583616
